# %%
import numpy as np
from model import *
from planar import *
import matplotlib.pyplot as plt


X, Y = load_planar_dataset()

plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral)

# %%
print(X.shape, Y.shape)
neural_net = Model(X, Y.T).add_layer({'hidden_unit': 8, 'activation': "Relu"}).add_layer({'hidden_unit': 6, 'activation': "Relu"}).add_layer({'hidden_unit': 4, 'activation': "Relu"}).add_layer({'hidden_unit': 1, 'activation': "Sigmoid"}).train(initalization_method="He", epoch=1000).predict()
# Out:
# (2, 400) (1, 400)
#
# Cost after iteration 0: 0.5964440184248125
#
# Cost after iteration 0: 0.5877803104850451
#
# Cost after iteration 0: 0.5793599287971154
#
# Cost after iteration 0: 0.5711727497268759
#
# Cost after iteration 0: 0.84252666389317
#
# Cost after iteration 0: 0.8289298737177466
#
# Cost after iteration 0: 0.8155010098368958
#
# Cost after iteration 0: 0.8022397611739267
#
# Cost after iteration 100: 0.7134640872675051
#
# Cost after iteration 100: 0.7020989922646749
#
# Cost after iteration 100: 0.6910558176981548
#
# Cost after iteration 100: 0.6803216900484942
#
# Cost after iteration 100: 0.7169640469018164
#
# Cost after iteration 100: 0.705778489574999
#
# Cost after iteration 100: 0.6947632270703135
#
# Cost after iteration 100: 0.6839165845921542
#
# Cost after iteration 200: 0.7131520897722438
#
# Cost after iteration 200: 0.7020916447622051
#
# Cost after iteration 200: 0.6913300022901833
#
# Cost after iteration 200: 0.6808558914058922
#
# ...
